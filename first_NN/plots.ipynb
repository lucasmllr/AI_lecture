# %%
from utils import *
from first_nn import *
import pylab as plt

# %%
#data loading
triple = ToyDataset('triple_junction_data_training.txt')
triple_test = ToyDataset('triple_junction_data_test.txt')
spiral = ToyDataset('spiral_data_training.txt')
spiral_test = ToyDataset('spiral_data_test.txt')

# %%
model_1 = train(model1, triple, triple_test, 100)
grid_evaluation(model_1, triple, round=False)
# Out:
# test accuracy in epoche 0 : 0.42333333333333334
# test accuracy in epoche 10 : 0.525
# test accuracy in epoche 20 : 0.6
# test accuracy in epoche 30 : 0.625
# test accuracy in epoche 40 : 0.6616666666666666
# test accuracy in epoche 50 : 0.6766666666666666
# test accuracy in epoche 60 : 0.7133333333333334
# test accuracy in epoche 70 : 0.7533333333333333
# test accuracy in epoche 80 : 0.7533333333333333
# test accuracy in epoche 90 : 0.7583333333333333

# %%
model_2 = train(model2, triple, triple_test, 100)
grid_evaluation(model_2, triple, round=False)
# Out:
# test accuracy in epoche 0 : 0.3333333333333333
# test accuracy in epoche 10 : 0.6233333333333333
# test accuracy in epoche 20 : 0.5133333333333333
# test accuracy in epoche 30 : 0.585
# test accuracy in epoche 40 : 0.6266666666666667
# test accuracy in epoche 50 : 0.6683333333333333
# test accuracy in epoche 60 : 0.7333333333333333
# test accuracy in epoche 70 : 0.7483333333333333
# test accuracy in epoche 80 : 0.765
# test accuracy in epoche 90 : 0.7816666666666666

# %%
#models are not copied deep in the following, therefore, they are trained for another 100 epoches
#hard boundaries of decision regions for model 1
model_3 = train(model1, triple, triple_test, 100)
grid_evaluation(model_3, triple, round=True)
# Out:
# test accuracy in epoche 0 : 0.77
# test accuracy in epoche 10 : 0.7833333333333333
# test accuracy in epoche 20 : 0.7983333333333333
# test accuracy in epoche 30 : 0.8083333333333333
# test accuracy in epoche 40 : 0.825
# test accuracy in epoche 50 : 0.8333333333333334
# test accuracy in epoche 60 : 0.8383333333333334
# test accuracy in epoche 70 : 0.855
# test accuracy in epoche 80 : 0.8533333333333334
# test accuracy in epoche 90 : 0.8533333333333334

# %%
model_4 = train(model2, triple, triple_test, 100)
grid_evaluation(model_4, triple, round=True)
# Out:
# test accuracy in epoche 0 : 0.7933333333333333
# test accuracy in epoche 10 : 0.7983333333333333
# test accuracy in epoche 20 : 0.8083333333333333
# test accuracy in epoche 30 : 0.8083333333333333
# test accuracy in epoche 40 : 0.8183333333333334
# test accuracy in epoche 50 : 0.8316666666666667
# test accuracy in epoche 60 : 0.8416666666666667
# test accuracy in epoche 70 : 0.8483333333333334
# test accuracy in epoche 80 : 0.85
# test accuracy in epoche 90 : 0.8516666666666667

# %%
#spiral data is very hard to fit
train(model2, spiral, spiral_test, 100)
grid_evaluation(model1, spiral, round=False)
# Out:
# test accuracy in epoche 0 : 0.3333333333333333
# test accuracy in epoche 10 : 0.3333333333333333
# test accuracy in epoche 20 : 0.3333333333333333
# test accuracy in epoche 30 : 0.3333333333333333
# test accuracy in epoche 40 : 0.3333333333333333
# test accuracy in epoche 50 : 0.3333333333333333
# test accuracy in epoche 60 : 0.3333333333333333
# test accuracy in epoche 70 : 0.3333333333333333
# test accuracy in epoche 80 : 0.3333333333333333
# test accuracy in epoche 90 : 0.3333333333333333
